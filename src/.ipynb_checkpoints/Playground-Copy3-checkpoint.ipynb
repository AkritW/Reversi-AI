# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import tensorflow as tf
from env import ReversiEnv

# %%
env = ReversiEnv()
log_path = os.path.join('Training', 'Logs')

# %%
policy_kwargs = dict(net_arch=[128, 128, 128, 128])
model = A2C("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Training/Logs/A2C_5
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.05      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 942       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -3.97     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -3.93e+03 |
# |    value_loss         | 9.69e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.24      |
# |    ep_rew_mean        | -997      |
# | time/                 |           |
# |    fps                | 933       |
# |    iterations         | 200       |
# ...

# %%
# model.save('A2C_966')

# %%
# model = PPO.load('PPO_987', env=env, tensorboard_log="./Training/Logs/", reset_num_timesteps=False)

# %%
# model.learn(total_timesteps=1000000, tb_log_name='PPO_1', reset_num_timesteps=False)
