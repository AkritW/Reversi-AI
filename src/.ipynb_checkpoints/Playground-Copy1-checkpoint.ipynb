# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import tensorflow as tf
from env import ReversiEnv

# %%
env = ReversiEnv()
log_path = os.path.join('Training', 'Logs')

# %%
policy_kwargs = dict(net_arch=[128, 128, 128, 128])
model = A2C("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Training/Logs/A2C_6
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.05      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1032      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -4.03     |
# |    explained_variance | -0.0176   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -4.08e+03 |
# |    value_loss         | 9.65e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.07      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1053      |
# |    iterations         | 200       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -3.6      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -3.54e+03 |
# |    value_loss         | 9.59e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.13      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1057      |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3.98     |
# |    explained_variance | -0.000619 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -4.2e+03  |
# |    value_loss         | 9.37e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.17      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1060      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -3.65     |
# |    explained_variance | -0.000748 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -3.43e+03 |
# |    value_loss         | 9.36e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.33      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1049      |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -3.72     |
# |    explained_variance | -1.63e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -3.02e+03 |
# |    value_loss         | 7.33e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.25      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1042      |
# |    iterations         | 600       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -3.76     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -3.76e+03 |
# |    value_loss         | 9.23e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.19      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1038      |
# |    iterations         | 700       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3.47     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -3.54e+03 |
# |    value_loss         | 9.14e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.28      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1035      |
# |    iterations         | 800       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.52     |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -2.62e+03 |
# |    value_loss         | 7.2e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.39      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1031      |
# |    iterations         | 900       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.75     |
# |    explained_variance | -4.41e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -3.37e+03 |
# |    value_loss         | 8.84e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.12      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1032      |
# |    iterations         | 1000      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -4.13     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -3.09e+03 |
# |    value_loss         | 7.1e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.08      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1032      |
# |    iterations         | 1100      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -4.12     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -3.72e+03 |
# |    value_loss         | 8.79e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.11      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1035      |
# |    iterations         | 1200      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -4.1      |
# |    explained_variance | -3.59e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -3.87e+03 |
# |    value_loss         | 8.67e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.1      |
# |    ep_rew_mean        | -1e+03   |
# | time/                 |          |
# |    fps                | 1038     |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -4.04    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -3.2e+03 |
# |    value_loss         | 6.9e+05  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.1       |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1040      |
# |    iterations         | 1400      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -4.01     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -3.13e+03 |
# |    value_loss         | 6.83e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.23      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1040      |
# |    iterations         | 1500      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -3.86     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -3.54e+03 |
# |    value_loss         | 8.46e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.41      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1039      |
# |    iterations         | 1600      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -3.45     |
# |    explained_variance | -1.39e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -3.53e+03 |
# |    value_loss         | 8.33e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.47      |
# |    ep_rew_mean        | -1e+03    |
# | time/                 |           |
# |    fps                | 1036      |
# |    iterations         | 1700      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -3.37     |
# |    explained_variance | -1.39e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -3.62e+03 |
# |    value_loss         | 8.25e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.62      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1033      |
# |    iterations         | 1800      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -2.74     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -3.47e+03 |
# |    value_loss         | 6.57e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.87      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1029      |
# |    iterations         | 1900      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -1.9      |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -2.43e+03 |
# |    value_loss         | 6.38e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.97      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1024      |
# |    iterations         | 2000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -2.05     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -2.09e+03 |
# |    value_loss         | 6.36e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.92      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1020      |
# |    iterations         | 2100      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -2.01     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -1.45e+03 |
# |    value_loss         | 6.29e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.94      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1017      |
# |    iterations         | 2200      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -1.75     |
# |    explained_variance | -7.39e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -1.95e+03 |
# |    value_loss         | 7.8e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.01      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1013      |
# |    iterations         | 2300      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -1.66     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -1.18e+03 |
# |    value_loss         | 6.16e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.96      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1010      |
# |    iterations         | 2400      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.79     |
# |    explained_variance | -8.7e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -1.06e+03 |
# |    value_loss         | 7.57e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.96      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1007      |
# |    iterations         | 2500      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -2.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -1.51e+03 |
# |    value_loss         | 6.04e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.99      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1005      |
# |    iterations         | 2600      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -2.72     |
# |    explained_variance | -1.12e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -2.2e+03  |
# |    value_loss         | 7.49e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1002      |
# |    iterations         | 2700      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -1.88     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -1.19e+03 |
# |    value_loss         | 5.91e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2         |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 1000      |
# |    iterations         | 2800      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.5      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -1.39e+03 |
# |    value_loss         | 5.85e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 998       |
# |    iterations         | 2900      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.82     |
# |    explained_variance | -7.51e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -2.21e+03 |
# |    value_loss         | 7.25e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.02      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 995       |
# |    iterations         | 3000      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.86     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -1.47e+03 |
# |    value_loss         | 5.72e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.04      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 992       |
# |    iterations         | 3100      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -1.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -1.41e+03 |
# |    value_loss         | 5.66e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.05      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 3200      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -1.42e+03 |
# |    value_loss         | 5.6e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.08      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3300      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -2.12     |
# |    explained_variance | -1.12e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -1.49e+03 |
# |    value_loss         | 6.95e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.1       |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 3400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -2.43     |
# |    explained_variance | -1.12e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -2.03e+03 |
# |    value_loss         | 6.87e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.07     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 986      |
# |    iterations         | 3500     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -996     |
# |    value_loss         | 6.79e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.95      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 3600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.96     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -2.18e+03 |
# |    value_loss         | 5.4e+05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.12     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 3700     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -2.01    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -2.4e+03 |
# |    value_loss         | 5.34e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.01      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 982       |
# |    iterations         | 3800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -2.47     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -1.39e+03 |
# |    value_loss         | 2.66e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.07      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 980       |
# |    iterations         | 3900      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.87     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -1.51e+03 |
# |    value_loss         | 5.18e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.07      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 979       |
# |    iterations         | 4000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -2.66     |
# |    explained_variance | -3.22e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -1.77e+03 |
# |    value_loss         | 6.36e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.06      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 978       |
# |    iterations         | 4100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.95     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -1.22e+03 |
# |    value_loss         | 5.07e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.99     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 977      |
# |    iterations         | 4200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -2.18    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -975     |
# |    value_loss         | 3.78e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.02      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 976       |
# |    iterations         | 4300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.7      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -2.49e+03 |
# |    value_loss         | 6.21e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.05      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 975       |
# |    iterations         | 4400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -2.06     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -1.54e+03 |
# |    value_loss         | 4.9e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 974       |
# |    iterations         | 4500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -1.97     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -1.84e+03 |
# |    value_loss         | 4.87e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.21      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 973       |
# |    iterations         | 4600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -2.46     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -2.34e+03 |
# |    value_loss         | 6e+05     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.28      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 972       |
# |    iterations         | 4700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -1.72     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -1.41e+03 |
# |    value_loss         | 4.73e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.17      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 970       |
# |    iterations         | 4800      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -1.67e+03 |
# |    value_loss         | 3.52e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 968       |
# |    iterations         | 4900      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.34     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -1.59e+03 |
# |    value_loss         | 4.65e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.25     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 967      |
# |    iterations         | 5000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -680     |
# |    value_loss         | 5.65e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.19      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 967       |
# |    iterations         | 5100      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.08     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -1.08e+03 |
# |    value_loss         | 4.38e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.33      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 966       |
# |    iterations         | 5200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.95     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -1.31e+03 |
# |    value_loss         | 3.36e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.34     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 965      |
# |    iterations         | 5300     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -1e+03   |
# |    value_loss         | 4.27e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.22      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 965       |
# |    iterations         | 5400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -1.72e+03 |
# |    value_loss         | 4.34e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.64      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 964       |
# |    iterations         | 5500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.1      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -1.99e+03 |
# |    value_loss         | 5.38e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.45      |
# |    ep_rew_mean        | -999      |
# | time/                 |           |
# |    fps                | 963       |
# |    iterations         | 5600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -1.77e+03 |
# |    value_loss         | 4.21e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 962       |
# |    iterations         | 5700      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.2      |
# |    explained_variance | -3.22e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -723      |
# |    value_loss         | 5.18e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.66     |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 961      |
# |    iterations         | 5800     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.978   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -248     |
# |    value_loss         | 5.12e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.7       |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 961       |
# |    iterations         | 5900      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.54     |
# |    explained_variance | 3.28e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -1.08e+03 |
# |    value_loss         | 5.05e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.6      |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 960      |
# |    iterations         | 6000     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -674     |
# |    value_loss         | 4.99e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.68      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 959       |
# |    iterations         | 6100      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -1.83     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -1.35e+03 |
# |    value_loss         | 4.93e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.38     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 959      |
# |    iterations         | 6200     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -621     |
# |    value_loss         | 4.86e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.55      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 958       |
# |    iterations         | 6300      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -2.38e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -575      |
# |    value_loss         | 4.8e+05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.61     |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 957      |
# |    iterations         | 6400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -894     |
# |    value_loss         | 2.88e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 957      |
# |    iterations         | 6500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.82    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -75.6    |
# |    value_loss         | 2.79e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.79      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 956       |
# |    iterations         | 6600      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -132      |
# |    value_loss         | 2.75e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.59      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 955       |
# |    iterations         | 6700      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.654    |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -448      |
# |    value_loss         | 3.65e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.6      |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 954      |
# |    iterations         | 6800     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.442   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -475     |
# |    value_loss         | 3.6e+05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.61     |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 954      |
# |    iterations         | 6900     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -450     |
# |    value_loss         | 3.55e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.8       |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 953       |
# |    iterations         | 7000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.761    |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -1.97e+03 |
# |    value_loss         | 3.5e+05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.71     |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 953      |
# |    iterations         | 7100     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.846   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -389     |
# |    value_loss         | 2.62e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.54      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 952       |
# |    iterations         | 7200      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.544    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -215      |
# |    value_loss         | 3.4e+05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.43     |
# |    ep_rew_mean        | -999     |
# | time/                 |          |
# |    fps                | 952      |
# |    iterations         | 7300     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -396     |
# |    value_loss         | 4.19e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.57      |
# |    ep_rew_mean        | -998      |
# | time/                 |           |
# |    fps                | 951       |
# |    iterations         | 7400      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.957    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -1.75e+03 |
# |    value_loss         | 2.52e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.5      |
# |    ep_rew_mean        | -998     |
# | time/                 |          |
# |    fps                | 950      |
# |    iterations         | 7500     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# ...
# |    entropy_loss       | -0.313   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23699    |
# |    policy_loss        | 1.3      |
# |    value_loss         | 779      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14       |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 808      |
# |    iterations         | 23800    |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 119000   |
# | train/                |          |
# |    entropy_loss       | -0.0109  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23799    |
# |    policy_loss        | 0.0223   |
# |    value_loss         | 823      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 807      |
# |    iterations         | 23900    |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 119500   |
# | train/                |          |
# |    entropy_loss       | -0.00566 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23899    |
# |    policy_loss        | 0.0218   |
# |    value_loss         | 773      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 806      |
# |    iterations         | 24000    |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23999    |
# |    policy_loss        | -4.92    |
# |    value_loss         | 1.3e+04  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.4     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 24100    |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 120500   |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24099    |
# |    policy_loss        | -49.9    |
# |    value_loss         | 5.32e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14       |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 804      |
# |    iterations         | 24200    |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 121000   |
# | train/                |          |
# |    entropy_loss       | -0.00298 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24199    |
# |    policy_loss        | 0.00576  |
# |    value_loss         | 764      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.8     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 24300    |
# |    time_elapsed       | 151      |
# |    total_timesteps    | 121500   |
# | train/                |          |
# |    entropy_loss       | -0.109   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24299    |
# |    policy_loss        | 0.241    |
# |    value_loss         | 778      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.7     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 802      |
# |    iterations         | 24400    |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.253   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24399    |
# |    policy_loss        | -243     |
# |    value_loss         | 1.36e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.9     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 24500    |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 122500   |
# | train/                |          |
# |    entropy_loss       | -0.372   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24499    |
# |    policy_loss        | -226     |
# |    value_loss         | 2.58e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 24600    |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 123000   |
# | train/                |          |
# |    entropy_loss       | -0.311   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24599    |
# |    policy_loss        | -16.7    |
# |    value_loss         | 3.74e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 24700    |
# |    time_elapsed       | 154      |
# |    total_timesteps    | 123500   |
# | train/                |          |
# |    entropy_loss       | -0.0814  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24699    |
# |    policy_loss        | 0.153    |
# |    value_loss         | 779      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 798      |
# |    iterations         | 24800    |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.00165 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24799    |
# |    policy_loss        | 0.00321  |
# |    value_loss         | 746      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 797      |
# |    iterations         | 24900    |
# |    time_elapsed       | 156      |
# |    total_timesteps    | 124500   |
# | train/                |          |
# |    entropy_loss       | -0.00309 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24899    |
# |    policy_loss        | -509     |
# |    value_loss         | 1.45e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 25000    |
# |    time_elapsed       | 156      |
# |    total_timesteps    | 125000   |
# | train/                |          |
# |    entropy_loss       | -0.0136  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24999    |
# |    policy_loss        | 0.0177   |
# |    value_loss         | 786      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 795      |
# |    iterations         | 25100    |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 125500   |
# | train/                |          |
# |    entropy_loss       | -0.0998  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25099    |
# |    policy_loss        | 0.232    |
# |    value_loss         | 754      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 794      |
# |    iterations         | 25200    |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25199    |
# |    policy_loss        | -34.2    |
# |    value_loss         | 6.2e+04  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.2     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 793      |
# |    iterations         | 25300    |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 126500   |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25299    |
# |    policy_loss        | 0.246    |
# |    value_loss         | 748      |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 model.learn(total_timesteps=1000000)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/a2c/a2c.py:203, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     189 def learn(
#     190     self: A2CSelf,
#     191     total_timesteps: int,
#    (...)
#     200     progress_bar: bool = False,
#     201 ) -> A2CSelf:
# --> 203     return super().learn(
#     204         total_timesteps=total_timesteps,
#     205         callback=callback,
#     206         log_interval=log_interval,
#     207         eval_env=eval_env,
#     208         eval_freq=eval_freq,
#     209         n_eval_episodes=n_eval_episodes,
#     210         tb_log_name=tb_log_name,
#     211         eval_log_path=eval_log_path,
#     212         reset_num_timesteps=reset_num_timesteps,
#     213         progress_bar=progress_bar,
#     214     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:262, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     258 callback.on_training_start(locals(), globals())
#     260 while self.num_timesteps < total_timesteps:
# --> 262     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     264     if continue_training is False:
#     265         break
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:181, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     178 if isinstance(self.action_space, gym.spaces.Box):
#     179     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 181 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     183 self.num_timesteps += env.num_envs
#     185 # Give access to local variables
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File ~/Codes/Reversi-AI/src/env.py:109, in ReversiEnv.step(self, action)
#     106     self.reset()
#     108 # state of board after place
# --> 109 state = self.encode_board3()
#     111 # count reward
#     112 # newly flipped disk
#     113 reward = disk_flipped - 1  # * 10
#
# File ~/Codes/Reversi-AI/src/env.py:70, in ReversiEnv.encode_board3(self)
#      58 board1 = np.array(
#      59     [
#      60         [1 if x == 1 else 0 for x in self.reversi.board[y]]
#      61         for y, _ in enumerate(self.reversi.board)
#      62     ]
#      63 )
#      64 board2 = np.array(
#      65     [
#      66         [1 if x == -1 else 0 for x in self.reversi.board[y]]
#      67         for y, _ in enumerate(self.reversi.board)
#      68     ]
#      69 )
# ---> 70 board3 = self.reversi.get_valid_board()
#      72 return np.append(
#      73     np.concatenate((board1, board2, board3), axis=0).reshape(-1),
#      74     self.reversi.player,
#      75 )
#
# File ~/Codes/Reversi-AI/src/game.py:103, in Reversi.get_valid_board(self)
#     102 def get_valid_board(self):
# --> 103     valid_coords = self.get_valid_position(self.player)
#     104     valid_board = np.array([[0 for _ in range(8)] for _ in range(8)])
#     105     for coord in valid_coords:
#
# File ~/Codes/Reversi-AI/src/game.py:56, in Reversi.get_valid_position(self, player)
#      47 if (
#      48     x != 7
#      49     and self.board[y, x + 1] != 0
#      50     and self.place(self.player, (y, x))[1] != 1
#      51 ):
#      52     valid_pos.append((y, x))
#      53 elif (
#      54     x != 0
#      55     and self.board[y, x - 1] != 0
# ---> 56     and self.place(self.player, (y, x))[1] != 1
#      57 ):
#      58     valid_pos.append((y, x))
#      59 elif (
#      60     y != 7
#      61     and self.board[y + 1, x] != 0
#      62     and self.place(self.player, (y, x))[1] != 1
#      63 ):
#
# File ~/Codes/Reversi-AI/src/game.py:181, in Reversi.place(self, player, position)
#     179 for i in range(1, 8 - y, 1):
#     180     if player == Player.USER.value:
# --> 181         if board[y + i, x] == 0:
#     182             break
#     183         elif board[y + i, x] == 1:
#
# KeyboardInterrupt:

# %%
# model.save('A2C_966')

# %%
# model = PPO.load('PPO_987', env=env, tensorboard_log="./Training/Logs/", reset_num_timesteps=False)

# %%
# model.learn(total_timesteps=1000000, tb_log_name='PPO_1', reset_num_timesteps=False)

# %%
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]
# Logging to Training/Logs/A2C_6
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 13.6      |
# |    ep_rew_mean        | -986      |
# | time/                 |           |
# |    fps                | 584       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -0.000844 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25455     |
# |    policy_loss        | 0.00157   |
# |    value_loss         | 728       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 13.2      |
# |    ep_rew_mean        | -987      |
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.00118  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25555     |
# |    policy_loss        | 0.00221   |
# |    value_loss         | 726       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13       |
# |    ep_rew_mean        | -987     |
# | time/                 |          |
# |    fps                | 613      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.0137  |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25655    |
# |    policy_loss        | -492     |
# |    value_loss         | 1.57e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.8     |
# |    ep_rew_mean        | -987     |
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25755    |
# |    policy_loss        | -8.91    |
# |    value_loss         | 4.27e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.1     |
# |    ep_rew_mean        | -987     |
# | time/                 |          |
# |    fps                | 611      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.00123 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25855    |
# |    policy_loss        | 0.00229  |
# |    value_loss         | 719      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.6     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 600      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.00135 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25955    |
# |    policy_loss        | 0.00295  |
# |    value_loss         | 716      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 606      |
# |    iterations         | 700      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.233   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26055    |
# |    policy_loss        | -24.2    |
# |    value_loss         | 1.63e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.1     |
# |    ep_rew_mean        | -986     |
# | time/                 |          |
# |    fps                | 605      |
# |    iterations         | 800      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.00082 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26155    |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 710      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.2      |
# |    ep_rew_mean        | -986      |
# | time/                 |           |
# |    fps                | 605       |
# |    iterations         | 900       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.000878 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26255     |
# |    policy_loss        | 0.0015    |
# |    value_loss         | 707       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.4     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 604      |
# |    iterations         | 1000     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26355    |
# |    policy_loss        | -381     |
# |    value_loss         | 5.89e+04 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.5      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 1100      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.00865  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26455     |
# |    policy_loss        | 0.0134    |
# |    value_loss         | 746       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.6     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 601      |
# |    iterations         | 1200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.366   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26555    |
# |    policy_loss        | -185     |
# |    value_loss         | 3.27e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.6     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 600      |
# |    iterations         | 1300     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.0541  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26655    |
# |    policy_loss        | 0.0928   |
# |    value_loss         | 724      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.8     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 600      |
# |    iterations         | 1400     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.224   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26755    |
# |    policy_loss        | -239     |
# |    value_loss         | 1.77e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.6     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 599      |
# |    iterations         | 1500     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.221   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26855    |
# |    policy_loss        | -119     |
# |    value_loss         | 6.27e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.5     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 598      |
# |    iterations         | 1600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 26955    |
# |    policy_loss        | -42.7    |
# |    value_loss         | 6.35e+04 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.5      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 598       |
# |    iterations         | 1700      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.000804 |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27055     |
# |    policy_loss        | 0.0015    |
# |    value_loss         | 684       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.8      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 598       |
# |    iterations         | 1800      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.243    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27155     |
# |    policy_loss        | -13.9     |
# |    value_loss         | 5.06e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.7      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 598       |
# |    iterations         | 1900      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.0013   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27255     |
# |    policy_loss        | 0.00396   |
# |    value_loss         | 678       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.7      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 598       |
# |    iterations         | 2000      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0422   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27355     |
# |    policy_loss        | 0.0872    |
# |    value_loss         | 691       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.5      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 597       |
# |    iterations         | 2100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.00389  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27455     |
# |    policy_loss        | 0.00483   |
# |    value_loss         | 716       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.6      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 597       |
# |    iterations         | 2200      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.286    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27555     |
# |    policy_loss        | -20.8     |
# |    value_loss         | 5.3e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.6      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 598       |
# |    iterations         | 2300      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.00135  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27655     |
# |    policy_loss        | 0.00469   |
# |    value_loss         | 666       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.7     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 598      |
# |    iterations         | 2400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.26    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 27755    |
# |    policy_loss        | 0.785    |
# |    value_loss         | 663      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.6     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 597      |
# |    iterations         | 2500     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 27855    |
# |    policy_loss        | -90.2    |
# |    value_loss         | 7.02e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.7     |
# |    ep_rew_mean        | -985     |
# | time/                 |          |
# |    fps                | 596      |
# |    iterations         | 2600     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.401   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 27955    |
# |    policy_loss        | -87.5    |
# |    value_loss         | 3.84e+04 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 14.9      |
# |    ep_rew_mean        | -985      |
# | time/                 |           |
# |    fps                | 595       |
# |    iterations         | 2700      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.000412 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28055     |
# |    policy_loss        | 0.000778  |
# |    value_loss         | 654       |
# -------------------------------------
# Stopping engine(s): 1673190019
# engine set stopped 1673190019: {'engines': {'0': {'exit_code': 0, 'pid': 94999, 'identifier': '0'}, '1': {'exit_code': 0, 'pid': 95009, 'identifier': '1'}, '2': {'exit_code': 0, 'pid': 95010, 'identifier': '2'}, '3': {'exit_code': 0, 'pid': 95011, 'identifier': '3'}, '4': {'exit_code': 0, 'pid': 95012, 'identifier': '4'}, '5': {'exit_code': 0, 'pid': 95013, 'identifier': '5'}, '6': {'exit_code': 0, 'pid': 95014, 'identifier': '6'}, '7': {'exit_code': 0, 'pid': 95015, 'identifier': '7'}}, 'exit_code': 0}
# Stopping controller
# Controller stopped: {'exit_code': 0, 'pid': 94996, 'identifier': 'ipcontroller-1673190018-6f7d-94793'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#       2 import ipyparallel as ipp
#       4 with ipp.Cluster() as rc:
# ----> 5     model.learn(total_timesteps=1000000)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/a2c/a2c.py:203, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     189 def learn(
#     190     self: A2CSelf,
#     191     total_timesteps: int,
#    (...)
#     200     progress_bar: bool = False,
#     201 ) -> A2CSelf:
# --> 203     return super().learn(
#     204         total_timesteps=total_timesteps,
#     205         callback=callback,
#     206         log_interval=log_interval,
#     207         eval_env=eval_env,
#     208         eval_freq=eval_freq,
#     209         n_eval_episodes=n_eval_episodes,
#     210         tb_log_name=tb_log_name,
#     211         eval_log_path=eval_log_path,
#     212         reset_num_timesteps=reset_num_timesteps,
#     213         progress_bar=progress_bar,
#     214     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:283, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     280         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     281         self.logger.dump(step=self.num_timesteps)
# --> 283     self.train()
#     285 callback.on_training_end()
#     287 return self
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/stable_baselines3/a2c/a2c.py:172, in A2C.train(self)
#     170 # Optimization step
#     171 self.policy.optimizer.zero_grad()
# --> 172 loss.backward()
#     174 # Clip grad norm
#     175 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
